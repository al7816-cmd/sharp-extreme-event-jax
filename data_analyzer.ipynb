# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_eta = np.load('data/obs_0.5_date_2026_03_24_20_54_42/inst_eta.npy')

# %%
inst_eta
# Out:
# array([[-1.69493483e-03,  1.66069115e-03],
#        [-1.73092080e-03,  1.65093095e-03],
#        [-1.76701397e-03,  1.64083803e-03],
#        ...,
#        [ 2.41451288e-01, -4.94685576e-03],
#        [ 2.43505942e-01, -6.44144313e-09],
#        [ 2.44952495e-01,  3.55951449e-01]])
